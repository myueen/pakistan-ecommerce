# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import sklearn

from pandas import Series, DataFrame
from matplotlib import rcParams

# %%
df = pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')
# Out:
# /var/folders/dr/k6wp_5ns5hj632l6j_ks1nc80000gn/T/ipykernel_13321/3310234197.py:1: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
# grand_total = df['grand_total']
# grand_total.plot()
price = df['price']
price.plot()
# Out:
# <Axes: >

# %%
date = df['created_at']
date.loc['7/1/2016':'7/1/2017']
date
# Out:
# 0          7/1/2016
# 1          7/1/2016
# 2          7/1/2016
# 3          7/1/2016
# 4          7/1/2016
#              ...
# 1048570         NaN
# 1048571         NaN
# 1048572         NaN
# 1048573         NaN
# 1048574         NaN
# Name: created_at, Length: 1048575, dtype: object

# %%
df = df.iloc[:584500, :21]
df
# Out:
#          item_id          status created_at  \
# 0       211131.0        complete   7/1/2016
# 1       211133.0        canceled   7/1/2016
# 2       211134.0        canceled   7/1/2016
# 3       211135.0        complete   7/1/2016
# 4       211136.0  order_refunded   7/1/2016
# ...          ...             ...        ...
# 584495  905175.0        canceled  8/28/2018
# 584496  905177.0      processing  8/28/2018
# 584497  905179.0            paid  8/28/2018
# 584498  905180.0        canceled  8/28/2018
# 584499  905181.0        canceled  8/28/2018
#
#                                                       sku    price  \
# 0                                       kreations_YI 06-L   1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...    240.0
# 2                                      Ego_UP0017-999-MR0   2450.0
# 3                                          kcc_krone deal    360.0
# 4                                             BK7010400AG    555.0
# ...

# %%
quantitative = df.loc[:, ('price', 'qty_ordered', 'grand_total', 'discount_amount', 'Customer ID')]
quantitative
# Out:
#           price  qty_ordered  grand_total  discount_amount  Customer ID
# 0        1950.0          1.0       1950.0              0.0          1.0
# 1         240.0          1.0        240.0              0.0          2.0
# 2        2450.0          1.0       2450.0              0.0          3.0
# 3         360.0          1.0         60.0            300.0          4.0
# 4         555.0          2.0       1110.0              0.0          5.0
# ...         ...          ...          ...              ...          ...
# 584495   1048.0          1.0       1298.0              0.0     115322.0
# 584496   1048.0          1.0       1298.0              0.0     115322.0
# 584497  44199.0          1.0      44499.0              0.0     115323.0
# 584498   3789.0          1.0       5737.0              0.0     114062.0
# 584499   1698.0          1.0       5737.0              0.0     114062.0
#
# [584500 rows x 5 columns]

# %%
ts = df.set_index('created_at')
ts = ts.loc[:, 'grand_total']
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: xlabel='created_at'>
